# %% [markdown]
# Данный файл - не задание. Просто необходимо было изучить материалы по визуализации. ЗДЕСЬ НЕТ ФАЙЛА MPG для чтения!!! Русакова просто его не скидывала. Это чисто пример, не более

# %% [markdown]
# ### Задание
# Изучите материалы о визуализации модели линейной регресси и проверьте работу функций на данных, приведённых ниже.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures  # Класс преобразователь
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
 sns.lmplot(x="mpg", y="horsepower", data=mpg)

# %%
sns.lmplot(x="mpg", y="displacement", data=mpg)

# %%
mpg = sns.load_dataset("mpg")
iris = sns.load_dataset("iris")


sns.regplot(x="horsepower", y="displacement", data=mpg)

iris_mod = iris[iris["species"] == "setosa"]
sns.regplot(x="sepal_length", y="sepal_width", data=iris_mod, color='r')

sns.lmplot(x="sepal_width", y="petal_width", hue="species", data=iris)
plt.show()
